# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### CSV into DATAFRAME

# %%
geoplaces_csv_file = "geoplaces2.csv"
geoplaces_data_df = pd.read_csv(geoplaces_csv_file)
geoplaces_data_df.head(2)
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
#
#                                       the_geom_meter             name  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...  Kiku Cuernavaca
# 1  0101000020957F00001AD016568C4858C1243261274BA5...  puesto de tacos
#
#                                   address        city    state country fax  \
# 0                              Revolucion  Cuernavaca  Morelos  Mexico   ?
# 1  esquina santos degollado y leon guzman      s.l.p.   s.l.p.  mexico   ?
#
#    ...            alcohol smoking_area dress_code     accessibility   price  \
# 0  ...  No_Alcohol_Served         none   informal  no_accessibility  medium
# 1  ...  No_Alcohol_Served         none   informal        completely     low
#
#                      url Rambience franchise    area other_services
# 0  kikucuernavaca.com.mx  familiar         f  closed           none
# ...

# %%
rating_final_csv_file = "rating_final.csv"
rating_final_data_df = pd.read_csv(rating_final_csv_file)
rating_final_data_df.head(2)
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1

# %% [markdown]
# ### Merge Rating -> Geoplaces

# %%
geoplaces_data_df.merge(rating_final_data_df, left_on='placeID', right_on='placeID',how='outer')
# Out:
#       placeID   latitude   longitude  \
# 0      134999  18.915421  -99.184871
# 1      134999  18.915421  -99.184871
# 2      134999  18.915421  -99.184871
# 3      134999  18.915421  -99.184871
# 4      134999  18.915421  -99.184871
# 5      132825  22.147392 -100.983092
# 6      132825  22.147392 -100.983092
# 7      132825  22.147392 -100.983092
# 8      132825  22.147392 -100.983092
# 9      132825  22.147392 -100.983092
# 10     132825  22.147392 -100.983092
# 11     132825  22.147392 -100.983092
# 12     132825  22.147392 -100.983092
# 13     132825  22.147392 -100.983092
# 14     132825  22.147392 -100.983092
# 15     132825  22.147392 -100.983092
# 16     132825  22.147392 -100.983092
# 17     132825  22.147392 -100.983092
# 18     132825  22.147392 -100.983092
# 19     132825  22.147392 -100.983092
# 20     132825  22.147392 -100.983092
# 21     132825  22.147392 -100.983092
# 22     132825  22.147392 -100.983092
# 23     132825  22.147392 -100.983092
# ...

# %%
geoplaces_data_df.drop_duplicates("placeID", inplace=True)
geoplaces_data_df.set_index("placeID", inplace=True)

geoplaces_data_df.head()
# Out:
#           latitude   longitude  \
# placeID
# 134999   18.915421  -99.184871
# 132825   22.147392 -100.983092
# 135106   22.149709 -100.976093
# 132667   23.752697  -99.163359
# 132613   23.752903  -99.165076
#
#                                             the_geom_meter  \
# placeID
# 134999   0101000020957F000088568DE356715AC138C0A525FC46...
# 132825   0101000020957F00001AD016568C4858C1243261274BA5...
# 135106   0101000020957F0000649D6F21634858C119AE9BF528A3...
# 132667   0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 132613   0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                                    name  \
# placeID
# 134999                  Kiku Cuernavaca
# 132825                  puesto de tacos
# 135106       El Rinc�n de San Francisco
# 132667   little pizza Emilio Portes Gil
# 132613                    carnitas_mata
#
#                                         address             city  \
# placeID
# ...

# %%
geoplaces_data_df.to_csv('output_merge_placeid.csv')
